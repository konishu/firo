# %%
import pandas as pd
import numpy as np

import glob
import os
import sys
import math
from decimal import Decimal, ROUND_HALF_UP

# %%
#データの読み込み
data = pd.read_csv("data/A1.log",header=None)



#ヘッダーないので作る
header = ["GPGGA","UTC時間","緯度","北緯or南緯","経度","東経or西経","位置特定品質","補足している衛星数","水平精度低下率","アンテナの海抜高さ","メートル","ジオイド高","メートル","DPGSデータの最後の...","作動基準地点IDとチェックサム"]
#データと合わせる
data.columns = header
data.head(20)
# Out:
#      GPGGA    UTC時間           緯度 北緯or南緯            経度 東経or西経  位置特定品質  \
# 0   $GPGGA  14521.0  3444.138273      N  13550.444149      E     4.0
# 1   $GPGGA  14522.0  3444.138274      N  13550.444149      E     4.0
# 2   $GPGGA  14523.0  3444.138274      N  13550.444148      E     4.0
# 3   $GPGGA  14524.0  3444.138275      N  13550.444148      E     4.0
# 4   $GPGGA  14525.0  3444.138273      N  13550.444146      E     4.0
# 5   $GPGGA  14526.0  3444.138273      N  13550.444149      E     4.0
# 6   $GPGGA  14527.0  3444.138275      N  13550.444149      E     4.0
# 7   $GPGGA  14528.0  3444.138274      N  13550.444148      E     4.0
# 8   $GPGGA  14529.0  3444.138274      N  13550.444147      E     4.0
# 9   $GPGGA  14530.0  3444.138273      N  13550.444149      E     4.0
# 10  $GPGGA  14531.0  3444.138274      N  13550.444148      E     4.0
# 11  $GPGGA  14532.0  3444.138274      N  13550.444148      E     4.0
# 12  $GPGGA  14533.0  3444.138273      N  13550.444149      E     4.0
# 13  $GPGGA  14534.0  3444.138274      N  13550.444148      E     4.0
# 14  $GPGGA  14535.0  3444.138274      N  13550.444149      E     4.0
# 15  $GPGGA  14536.0  3444.138273      N  13550.444148      E     4.0
# 16  $GPGGA  14537.0  3444.138273      N  13550.444150      E     4.0
# 17  $GPGGA  14538.0  3444.138274      N  13550.444147      E     4.0
# 18  $GPGGA  14539.0  3444.138273      N  13550.444147      E     4.0
# 19  $GPGGA  14540.0  3444.138273      N  13550.444148      E     4.0
#
#     補足している衛星数  水平精度低下率  アンテナの海抜高さ メートル    ジオイド高 メートル  DPGSデータの最後の...  \
# 0        12.0     1.01    74.9111    M  34.9866    M             0.0
# 1        12.0     1.01    74.9135    M  34.9866    M             0.0
# 2        12.0     1.01    74.9128    M  34.9866    M             0.0
# 3        12.0     1.01    74.9098    M  34.9866    M             0.0
# 4        12.0     1.01    74.9136    M  34.9866    M             0.0
# 5        12.0     1.01    74.9142    M  34.9866    M             0.0
# 6        12.0     1.01    74.9055    M  34.9866    M             0.0
# 7        12.0     1.02    74.9129    M  34.9866    M             0.0
# 8        12.0     1.02    74.9110    M  34.9866    M             0.0
# 9        12.0     1.02    74.9160    M  34.9866    M             0.0
# 10       12.0     1.02    74.9142    M  34.9866    M             0.0
# 11       12.0     1.02    74.9106    M  34.9866    M             0.0
# 12       12.0     1.02    74.9154    M  34.9866    M             0.0
# 13       12.0     1.02    74.9105    M  34.9866    M             0.0
# 14       12.0     1.02    74.9143    M  34.9866    M             0.0
# 15       12.0     1.02    74.9171    M  34.9866    M             0.0
# 16       12.0     1.02    74.9167    M  34.9866    M             0.0
# 17       12.0     1.02    74.9130    M  34.9866    M             0.0
# 18       12.0     1.02    74.9118    M  34.9866    M             0.0
# 19       12.0     1.02    74.9153    M  34.9866    M             0.0
#
#    作動基準地点IDとチェックサム
# 0          0000*49
# 1          0000*49
# 2          0000*42
# 3          0000*40
# 4          0000*45
# 5          0000*43
# 6          0000*48
# 7          0000*47
# 8          0000*48
# 9          0000*48
# 10         0000*4F
# 11         0000*4B
# 12         0000*41
# 13         0000*44
# 14         0000*4B
# 15         0000*45
# 16         0000*42
# 17         0000*45
# 18         0000*40
# 19         0000*4C

# %%
data = pd.read_csv("data/A1.log",header=None)

#ヘッダーないので作る
header = ["GPGGA","UTC時間","緯度","北緯or南緯","経度","東経or西経","位置特定品質","補足している衛星数","水平精度低下率","アンテナの海抜高さ","メートル","ジオイド高","メートル","DPGSデータの最後の...","作動基準地点IDとチェックサム"]
#データと合わせる
data.columns = header


#経度の計算
long = data["経度"]
sec = (long - long.round())*0.6
long_rad_min_sec = (long.round() + sec)/100
long = long_rad_min_sec.round(5).mode().mean()

long_rad = int(math.modf(long)[1])
long_min = int(math.modf((long-int(long))*100)[1])
long_sec = (sec*100).round(8).mode().mean()


# 緯度の計算
lat = data["緯度"]
sec = (lat - lat.round())*0.6
lat_rad_min_sec = (lat.round() + sec)/100
lat = lat_rad_min_sec.round(5).mode().mean()

lat_rad = int(math.modf(lat)[1])
lat_min = int(math.modf((lat-int(lat))*100)[1])
lat_sec = (sec*100).round(8).mode().mean()


print(str(lat_rad)+ "°" + str(lat_min) + "'" + str(lat_sec) , str(long_rad)+ "°" + str(long_min) + "'" + str(long_sec))

# print("経度:" + str(long) + "\n" + "緯度:" + str(lat))
# Out:
# 34°44'8.296398 135°50'26.64889628571429

# %%
def readlog_for_loop(fileslist):
    #ヘッダーないので作る
    header = ["GPGGA","UTC時間","緯度","北緯or南緯","経度","東経or西経","位置特定品質","補足している衛星数","水平精度低下率","アンテナの海抜高さ","メートル","ジオイド高","メートル","DPGSデータの最後の...","作動基準地点IDとチェックサム"]
    altitude = []
    longnitude = []
    for i,file in enumerate(fileslist):
        df = pd.read_csv(file,engine = "python")
        df.columns = header
        #経度の計算
        long = data["経度"]
        sec = (long - long.round())*0.6
        long_rad_min_sec = (long.round() + sec)/100
        long = long_rad_min_sec.round(5).mode().mean()

        long_rad = int(math.modf(long)[1])
        long_min = int(math.modf((long-int(long))*100)[1])
        long_sec = (sec*100).round(8).mode().mean()


        # 緯度の計算
        lat = data["緯度"]
        sec = (lat - lat.round())*0.6
        lat_rad_min_sec = (lat.round() + sec)/100
        lat = lat_rad_min_sec.round(5).mode().mean()

        lat_rad = int(math.modf(lat)[1])
        lat_min = int(math.modf((lat-int(lat))*100)[1])
        lat_sec = (sec*100).round(8).mode().mean()


        print(str(lat_rad)+ "°" + str(lat_min) + "'" + str(lat_sec) , str(long_rad)+ "°" + str(long_min) + "'" + str(long_sec))
    
        return lat_rad,lat_min,lat_sec,long_rad,long_min,long_sec
#     return longnitude, altitude

# %%
#ヘッダーないので作る
header = ["GPGGA","UTC時間","緯度","北緯or南緯","経度","東経or西経","位置特定品質","補足している衛星数","水平精度低下率","アンテナの海抜高さ","メートル","ジオイド高","メートル","DPGSデータの最後の...","作動基準地点IDとチェックサム"]
altitude = []
longnitude = []
for i,file in enumerate(fileslist):
    df = pd.read_csv(file,engine = "python")
    df.columns = header
    
    #経度の計算
    long = df["経度"]
    sec = (long - long.round())*0.6
    long_rad_min_sec = (long.round() + sec)/100
    long = long_rad_min_sec.round(5).mode().mean()

    long_rad = int(math.modf(long)[1])
    long_min = int(math.modf((long-int(long))*100)[1])
    long_sec = (sec*100).round(8).mode().mean()


    # 緯度の計算
    lat = df["緯度"]
    sec = (lat - lat.round())*0.6
    lat_rad_min_sec = (lat.round() + sec)/100
    lat = lat_rad_min_sec.round(5).mode().mean()

    lat_rad = int(math.modf(lat)[1])
    lat_min = int(math.modf((lat-int(lat))*100)[1])
    lat_sec = (sec*100).round(8).mode().mean()


    print(str(lat_rad)+ "°" + str(lat_min) + "'" + str(lat_sec) , str(long_rad)+ "°" + str(long_min) + "'" + str(long_sec) +"これは" + file +str(i))
# Out:
# 34°44'8.296398 135°50'26.64889628571429これは./data/A1.log0
# 34°44'8.229564 135°50'26.789680875000002これは./data/B1.log1
# 34°44'8.231088 135°50'26.5937808これは./data/C1.log2
# 34°44'8.050085999999999 135°50'26.769773999999998これは./data/D1.log3
# 34°44'8.050149428571428 135°50'26.615268これは./data/E1.log4
# 34°44'7.923396 135°50'26.771265これは./data/F1.log5
# 34°44'7.9236889090909095 135°50'26.615081999999997これは./data/G1.log6
# 34°44'7.856433 135°50'26.854329これは./data/H1.log7
# 34°44'7.64568 135°50'26.726441538461543これは./data/J1.log8
# 34°44'7.653745499999999 135°50'26.612142これは./data/K1.log9
# 34°44'7.717367076923076 135°50'24.2388075これは./data/L1.log10
# 34°44'7.838052428571429 135°50'24.24672これは./data/M1.log11
# 34°44'7.574082 135°50'24.159777これは./data/N1.log12
# 34°44'7.906044 135°50'24.155208これは./data/O1.log13
# 34°44'7.914702 135°50'23.916162これは./data/P1.log14
# 34°44'7.59765 135°50'23.886163384615386これは./data/R1.log15
# 34°44'7.560801 135°50'23.843934これは./data/S1.log16
# 34°44'7.56573 135°50'23.766888これは./data/T1.log17
# 34°44'7.44402 135°50'23.759991これは./data/U1.log18
# 34°44'7.443231999999999 135°50'23.843664これは./data/V1.log19
# 34°44'7.3939992000000005 135°50'24.016973999999998これは./data/W1.log20
# 34°44'7.438038 135°50'24.157254これは./data/X1.log21

# %%
def calc_xy(phi_deg, lambda_deg, phi0_deg, lambda0_deg):
    #(phi_deg, lambda_deg): 変換したい緯度・経度[度]（分・秒でなく小数であることに注意）
    #(phi0_deg, lambda0_deg): 平面直角座標系原点の緯度・経度[度]（分・秒でなく小数であることに注意）
    # 緯度経度・平面直角座標系原点をラジアンに直す
    phi_rad = np.deg2rad(phi_deg)
    lambda_rad = np.deg2rad(lambda_deg)
    phi0_rad = np.deg2rad(phi0_deg)
    lambda0_rad = np.deg2rad(lambda0_deg)
    
    # 補助関数
    def A_array(n):
        A0 = 1 + (n**2)/4. + (n**4)/64.
        A1 = -     (3./2)*( n - (n**3)/8. - (n**5)/64. ) 
        A2 =     (15./16)*( n**2 - (n**4)/4. )
        A3 = -   (35./48)*( n**3 - (5./16)*(n**5) )
        A4 =   (315./512)*( n**4 )
        A5 = -(693./1280)*( n**5 )
        return np.array([A0, A1, A2, A3, A4, A5])
  
    def alpha_array(n):
        a0 = np.nan # dummy
        a1 = (1./2)*n - (2./3)*(n**2) + (5./16)*(n**3) + (41./180)*(n**4) - (127./288)*(n**5)
        a2 = (13./48)*(n**2) - (3./5)*(n**3) + (557./1440)*(n**4) + (281./630)*(n**5)
        a3 = (61./240)*(n**3) - (103./140)*(n**4) + (15061./26880)*(n**5)
        a4 = (49561./161280)*(n**4) - (179./168)*(n**5)
        a5 = (34729./80640)*(n**5)
        return np.array([a0, a1, a2, a3, a4, a5])

    # 定数 (a, F: 世界測地系-測地基準系1980（GRS80）楕円体)
    m0 = 0.9999 
    a = 6378137.
    F = 298.257222101
    
   #各計算
    n = 1. / (2*F - 1)
    A_array = A_array(n)
    alpha_array = alpha_array(n)
        
    A_ = ( (m0*a)/(1.+n) )*A_array[0] # [m]
    S_ = ( (m0*a)/(1.+n) )*( A_array[0]*phi0_rad + np.dot(A_array[1:], np.sin(2*phi0_rad*np.arange(1,6))) ) # [m]
    
    lambda_c = np.cos(lambda_rad - lambda0_rad)
    lambda_s = np.sin(lambda_rad - lambda0_rad)
    
    t = np.sinh( np.arctanh(np.sin(phi_rad)) - ((2*np.sqrt(n)) / (1+n))*np.arctanh(((2*np.sqrt(n)) / (1+n)) * np.sin(phi_rad)) )
    t_ = np.sqrt(1 + t*t)

    xi2  = np.arctan(t / lambda_c) # [rad]
    eta2 = np.arctanh(lambda_s / t_)
    
    # (6) x, yの計算 (x: 変換後の平面直角座標[m] y: 変換後の平面直角座標[m])
    x = A_ * (xi2 + np.sum(np.multiply(alpha_array[1:],
                                       np.multiply(np.sin(2*xi2*np.arange(1,6)),
                                                   np.cosh(2*eta2*np.arange(1,6)))))) - S_ # [m]
    y = A_ * (eta2 + np.sum(np.multiply(alpha_array[1:],
                                        np.multiply(np.cos(2*xi2*np.arange(1,6)),
                                                    np.sinh(2*eta2*np.arange(1,6)))))) # [m]
    # return
    return x, y # [m]

# %%
phi_deg, lambda_deg, phi0_deg, lambda0_deg = map(float,input().split()) 
# 変換したい緯度経度と、原点の緯度経度を代入する
#   (phi_deg, lambda_deg ,phi0_deg, lambda0_deg): (変換したい緯度,経度, 平面直角座標系原点の緯度,経度)[度]（分・秒でなく小数であることに注意）
# 例：34.4413827 135.50444149999998 34.441382733000005 135.5044414827143

# phi0_deg = 34.441382733000005
# lambda0_deg = 135.5044414827143

# %%
X = []
Y = []
Colums = [x, y]

for i in range (len(fileslist)):
    phi_deg = altitude[i]
    lambda_deg = longnitude[i]
    x, y = calc_xy(phi_deg, lambda_deg, phi0_deg, lambda0_deg)
    X.append(x*(-1))
    Y.append(y)
#     print("変換後のX,Y座標はそれぞれx, y = ({0}, {1})".format(x, y))
df = pd.DataFrame([X,Y]).T

df

df.to_csv("map.csv", index =False, header = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c34ffe49cb94> in <module>
#       1 X = []
#       2 Y = []
# ----> 3 Colums = [x, y]
#       4
#       5 for i in range (len(fileslist)):
#
# NameError: name 'x' is not defined

# %%
x, y = calc_xy(phi_deg, lambda_deg, phi0_deg, lambda0_deg)
print("変換後のX,Y座標はそれぞれx, y = ({0}, {1})".format(x, y))
# 例のデータではx, y = (-107601.99377852166, -19708.02235489569)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-58147a9f75c3> in <module>
# ----> 1 x, y = calc_xy(phi_deg, lambda_deg, phi0_deg, lambda0_deg)
#       2 print("変換後のX,Y座標はそれぞれx, y = ({0}, {1})".format(x, y))
#       3 # 例のデータではx, y = (-107601.99377852166, -19708.02235489569)
#
# NameError: name 'phi_deg' is not defined

# %%
import folium
tokyo_station = [34.4413827, 135.50444149999998]
tokyo_tower = [34.4412405, 135.5039739]
gri = [34.441261, 135.5039612]

# %%
m = folium.Map(location=gri,
           tiles='OpenStreetMap',
           zoom_start=100)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
marker = folium.Marker(
    zoom_start=100,
    location=[34.44125, 135.505], 
    popup='hogehoge',                    
    icon=folium.Icon(color='orange'))
line = folium.vector_layers.PolyLine(
            locations=[tokyo_station,                     
                       gri,                          
                       tokyo_tower],                   
            color='black',                                  
            weight=1)
# マーカーと線の地図レイヤへの追加
m.add_child(marker)
m.add_child(line)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
